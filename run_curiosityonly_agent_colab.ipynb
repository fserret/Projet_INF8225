# %% [markdown]
# <a href="https://colab.research.google.com/github/fserret/Projet_INF8225/blob/master/run_curiosityonly_agent_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install cloudpickle==1.2
# Out:
# ...
# ERROR: tensorflow-probability 0.10.0rc0 has requirement cloudpickle>=1.2.2, but you'll have cloudpickle 1.2.0 which is incompatible.
# ...
#   Found existing installation: cloudpickle 1.3.0
#     Uninstalling cloudpickle-1.3.0:
#       Successfully uninstalled cloudpickle-1.3.0
# ...

# %%
pip install gym[atari]

# %%
# %tensorflow_version 1.x

import os
import tensorflow as tf

# Code to setup git repo in colab modified from https://github.com/tugstugi/dl-colab-notebooks/blob/master/notebooks/AlphaPoseV0_3_0.ipynb 

repo_url= "https://github.com/fserret/Projet_INF8225"

project_name = os.path.splitext(os.path.basename(repo_url))[0]

if not os.path.exists(project_name):
  # !git clone --recurse-submodules -j8 -q {repo_url}
  #!cd {project_name}
  
import sys
sys.path.append(project_name)
# Out:
# TensorFlow 1.x selected.

# %%
cd {project_name}
# Out:
# /content/Projet_INF8225

# %%
ls
# Out:
# graphicmaker/                 README.md                        Test.ipynb
# random-network-distillation/  README.tex.md                    tex/
# RapportProjet_INF8225/        run_imitation_agent_colab.ipynb

# %%
# !apt-get update && apt-get install cmake libopenmpi-dev python3-dev zlib1g-dev
# Out:
# Ign:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease
# Err:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ Release
#   404  Not Found [IP: 13.225.7.82 443]
# Hit:3 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:4 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Ign:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:6 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Ign:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:11 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:13 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease [15.4 kB]
# ...

# %%
# !git clone https://github.com/openai/baselines.git
# Out:
# Cloning into 'baselines'...
# remote: Enumerating objects: 3627, done.
# remote: Total 3627 (delta 0), reused 0 (delta 0), pack-reused 3627
# Receiving objects: 100% (3627/3627), 6.46 MiB | 3.29 MiB/s, done.
# Resolving deltas: 100% (2428/2428), done.

# %%
cd baselines/
# Out:
# /content/Projet_INF8225/baselines

# %%
# !python setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# creating baselines.egg-info
# writing baselines.egg-info/PKG-INFO
# writing dependency_links to baselines.egg-info/dependency_links.txt
# writing requirements to baselines.egg-info/requires.txt
# writing top-level names to baselines.egg-info/top_level.txt
# writing manifest file 'baselines.egg-info/SOURCES.txt'
# writing manifest file 'baselines.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/baselines
# copying baselines/results_plotter.py -> build/lib/baselines
# copying baselines/run.py -> build/lib/baselines
# copying baselines/__init__.py -> build/lib/baselines
# copying baselines/logger.py -> build/lib/baselines
# creating build/lib/baselines/trpo_mpi
# copying baselines/trpo_mpi/trpo_mpi.py -> build/lib/baselines/trpo_mpi
# ...

# %%
cd ../random-network-distillation/
# Out:
# /content/Projet_INF8225/random-network-distillation

# %%
cd ../
# Out:
# /content/Projet_INF8225

# %%
# !git submodule update --remote random-network-distillation
# Out:
# Submodule path 'random-network-distillation': checked out 'a868284bb6dca56e6df313f703c50f876b7666cf'

# %%
cd random-network-distillation/
# Out:
# /content/Projet_INF8225/random-network-distillation

# %%
# !python run_atari.py --num_env 8
# Out:
# Streaming output truncated to the last 5000 lines.
# | retintstd             | 0.0284    |
# | rewintmax_norm        | 0.0209    |
# | rewintmax_unnorm      | 0.0952    |
# | rewintmean_norm       | 0.00506   |
# | rewintmean_unnorm     | 0.0231    |
# | rewintstd_unnorm      | 0.0114    |
# | rewtotal              | 100       |
# | rooms                 | [1]       |
# | tcount                | 1.43e+06  |
# | time_elapsed          | 7.13e+03  |
# | tps                   | 202       |
# | vpredextmean          | -0.000153 |
# | vpredextstd           | 0.000236  |
# | vpredintmean          | 0.515     |
# | vpredintstd           | 0.0263    |
# | wait_policy_inference | 0.502     |
# | wait_step             | 5.06      |
# | wait_update           | 2.94      |
# -------------------------------------
# Rooms visited [1]
# Best return 100.0
# Best local return [100.0]
# eprews [0.0]
# n_rooms [1]
# Extrinsic coefficient 2.0
# Gamma 0.99
# Gamma ext 0.99
# All scores [0, 100]
# ...
